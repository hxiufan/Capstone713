# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('Ranking_History_studylink.govt.nz_12_27_2024_all.csv')

# %%
# Observe the dataset
df.head()
# Out:
#    TopLevel SecondLevel ThirdLevel FourthLevel FifthLevel  \
# 0  academic         NaN        NaN         NaN        NaN
# 1  academic         NaN        NaN         NaN        NaN
# 2  academic         NaN        NaN         NaN        NaN
# 3  academic         NaN        NaN         NaN        NaN
# 4  academic         NaN        NaN         NaN        NaN
#
#                                     Keyword  StartRank  EndRank  RankChange  \
# 0                                  academic        NaN       17         NaN
# 1                      otago academic dates        NaN       35         NaN
# 2  university of auckland academic calendar        NaN       79         NaN
# 3     auckland university academic calendar        NaN       74         NaN
# 4                      academic history vuw        NaN       66         NaN
#
#    EndClicks  ...  03/2024  04/2024  05/2024  06/2024  07/2024  08/2024  \
# 0         12  ...     14.0      NaN     18.0      NaN     16.0      NaN
# 1          0  ...      NaN      NaN     39.0      NaN     35.0      NaN
# 2          0  ...      NaN     91.0      NaN      NaN      NaN      NaN
# 3          0  ...      NaN     55.0      NaN     84.0      NaN      NaN
# 4          0  ...      NaN     66.0      NaN     70.0      NaN     77.0
#
#    09/2024  10/2024  11/2024  12/2024
# 0      NaN      NaN     17.0      NaN
# 1     36.0      NaN     35.0      NaN
# 2      NaN     80.0      NaN     79.0
# 3      NaN     74.0      NaN      NaN
# 4      NaN     66.0      NaN      NaN
#
# [5 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8532 entries, 0 to 8531
# Data columns (total 58 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TopLevel      8532 non-null   object
#  1   SecondLevel   2632 non-null   object
#  2   ThirdLevel    669 non-null    object
#  3   FourthLevel   122 non-null    object
#  4   FifthLevel    7 non-null      object
#  5   Keyword       8532 non-null   object
#  6   StartRank     0 non-null      float64
#  7   EndRank       8532 non-null   int64
#  8   RankChange    0 non-null      float64
#  9   EndClicks     8532 non-null   int64
#  10  ClicksChange  8532 non-null   int64
#  11  SearchVolume  1492 non-null   float64
#  12  03/2021       0 non-null      float64
#  13  04/2021       738 non-null    float64
#  14  05/2021       446 non-null    float64
#  15  06/2021       210 non-null    float64
#  16  07/2021       2229 non-null   float64
#  17  08/2021       884 non-null    float64
#  18  09/2021       1536 non-null   float64
#  19  10/2021       1433 non-null   float64
#  20  11/2021       1295 non-null   float64
#  21  12/2021       497 non-null    float64
#  22  01/2022       1977 non-null   float64
#  23  02/2022       446 non-null    float64
#  24  03/2022       734 non-null    float64
#  25  04/2022       1520 non-null   float64
#  26  05/2022       1421 non-null   float64
#  27  06/2022       1524 non-null   float64
#  28  07/2022       2006 non-null   float64
#  29  08/2022       2054 non-null   float64
#  30  09/2022       1816 non-null   float64
#  31  10/2022       2089 non-null   float64
#  32  11/2022       2053 non-null   float64
#  33  12/2022       1900 non-null   float64
#  34  01/2023       2117 non-null   float64
#  35  02/2023       2326 non-null   float64
#  36  03/2023       2222 non-null   float64
#  37  04/2023       1924 non-null   float64
#  38  05/2023       1990 non-null   float64
#  39  06/2023       2380 non-null   float64
#  40  07/2023       2195 non-null   float64
#  41  08/2023       2307 non-null   float64
#  42  09/2023       3168 non-null   float64
#  43  10/2023       2341 non-null   float64
#  44  11/2023       3384 non-null   float64
#  45  12/2023       2518 non-null   float64
#  46  01/2024       3171 non-null   float64
#  47  02/2024       2511 non-null   float64
#  48  03/2024       1056 non-null   float64
#  49  04/2024       2890 non-null   float64
#  50  05/2024       1666 non-null   float64
#  51  06/2024       2777 non-null   float64
#  52  07/2024       2356 non-null   float64
#  53  08/2024       2943 non-null   float64
#  54  09/2024       2449 non-null   float64
#  55  10/2024       3689 non-null   float64
#  56  11/2024       3145 non-null   float64
#  57  12/2024       3728 non-null   float64
# dtypes: float64(49), int64(3), object(6)
# memory usage: 3.8+ MB

# %%
# Drop specified columns
df.drop(columns=['TopLevel', 'SecondLevel', 'ThirdLevel', 'FourthLevel', 'FifthLevel'], inplace=True)

# %%
# Fill NaN values in numeric columns with 0
numeric_columns_to_fill = ['StartRank', 'EndRank', 'RankChange', 'EndClicks', 'ClicksChange', 'SearchVolume']
df[numeric_columns_to_fill] = df[numeric_columns_to_fill].fillna(0)

# %%
# Identify missing values in all columns
missing_values = df.isnull().sum()

# Display missing values
print(missing_values)

# Display the first few rows of the cleaned dataset
df.head()
# Out:
# Keyword            0
# StartRank          0
# EndRank            0
# RankChange         0
# EndClicks          0
# ClicksChange       0
# SearchVolume       0
# 03/2021         8532
# 04/2021         7794
# 05/2021         8086
# 06/2021         8322
# 07/2021         6303
# 08/2021         7648
# 09/2021         6996
# 10/2021         7099
# 11/2021         7237
# 12/2021         8035
# 01/2022         6555
# 02/2022         8086
# 03/2022         7798
# 04/2022         7012
# 05/2022         7111
# 06/2022         7008
# 07/2022         6526
# 08/2022         6478
# 09/2022         6716
# 10/2022         6443
# 11/2022         6479
# 12/2022         6632
# 01/2023         6415
# 02/2023         6206
# 03/2023         6310
# 04/2023         6608
# 05/2023         6542
# 06/2023         6152
# 07/2023         6337
# 08/2023         6225
# 09/2023         5364
# 10/2023         6191
# 11/2023         5148
# 12/2023         6014
# 01/2024         5361
# 02/2024         6021
# 03/2024         7476
# 04/2024         5642
# 05/2024         6866
# 06/2024         5755
# 07/2024         6176
# 08/2024         5589
# 09/2024         6083
# 10/2024         4843
# 11/2024         5387
# 12/2024         4804
# dtype: int64
#                                     Keyword  StartRank  EndRank  RankChange  \
# 0                                  academic        0.0       17         0.0
# 1                      otago academic dates        0.0       35         0.0
# 2  university of auckland academic calendar        0.0       79         0.0
# 3     auckland university academic calendar        0.0       74         0.0
# 4                      academic history vuw        0.0       66         0.0
#
#    EndClicks  ClicksChange  SearchVolume  03/2021  04/2021  05/2021  ...  \
# 0         12            12        1200.0      NaN      NaN      NaN  ...
# 1          0             0           0.0      NaN      NaN      NaN  ...
# 2          0             0           0.0      NaN      NaN      NaN  ...
# 3          0             0           0.0      NaN      NaN      NaN  ...
# 4          0             0           0.0      NaN      NaN      NaN  ...
#
#    03/2024  04/2024  05/2024  06/2024  07/2024  08/2024  09/2024  10/2024  \
# 0     14.0      NaN     18.0      NaN     16.0      NaN      NaN      NaN
# 1      NaN      NaN     39.0      NaN     35.0      NaN     36.0      NaN
# 2      NaN     91.0      NaN      NaN      NaN      NaN      NaN     80.0
# 3      NaN     55.0      NaN     84.0      NaN      NaN      NaN     74.0
# 4      NaN     66.0      NaN     70.0      NaN     77.0      NaN     66.0
#
#    11/2024  12/2024
# 0     17.0      NaN
# 1     35.0      NaN
# 2      NaN     79.0
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 53 columns]

# %%
# Ignore missing values in the dates columns

# %%
# Check for duplicate values in 'Keyword' column
duplicates = df['Keyword'].duplicated().sum()
print(f'Number of duplicate Keywords: {duplicates}')
# Out:
# Number of duplicate Keywords: 1963

# %%
# Remove duplicate rows based on 'Keyword', keeping the first occurrence
df = df.drop_duplicates(subset='Keyword', keep='first')

# %%
# Drop more columns which are not revlevance to our analysis
drop_columns = ['StartRank', 'RankChange', 'ClicksChange']
df = df.drop(columns=drop_columns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6569 entries, 0 to 8531
# Data columns (total 50 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Keyword       6569 non-null   object
#  1   EndRank       6569 non-null   int64
#  2   EndClicks     6569 non-null   int64
#  3   SearchVolume  6569 non-null   float64
#  4   03/2021       0 non-null      float64
#  5   04/2021       522 non-null    float64
#  6   05/2021       316 non-null    float64
#  7   06/2021       142 non-null    float64
#  8   07/2021       1613 non-null   float64
#  9   08/2021       642 non-null    float64
#  10  09/2021       1094 non-null   float64
#  11  10/2021       1023 non-null   float64
#  12  11/2021       924 non-null    float64
#  13  12/2021       358 non-null    float64
#  14  01/2022       1415 non-null   float64
#  15  02/2022       325 non-null    float64
#  16  03/2022       533 non-null    float64
#  17  04/2022       1095 non-null   float64
#  18  05/2022       1017 non-null   float64
#  19  06/2022       1086 non-null   float64
#  20  07/2022       1462 non-null   float64
#  21  08/2022       1474 non-null   float64
#  22  09/2022       1296 non-null   float64
#  23  10/2022       1497 non-null   float64
#  24  11/2022       1474 non-null   float64
#  25  12/2022       1389 non-null   float64
#  26  01/2023       1541 non-null   float64
#  27  02/2023       1668 non-null   float64
#  28  03/2023       1603 non-null   float64
#  29  04/2023       1381 non-null   float64
#  30  05/2023       1427 non-null   float64
#  31  06/2023       1715 non-null   float64
#  32  07/2023       1569 non-null   float64
#  33  08/2023       1678 non-null   float64
#  34  09/2023       2314 non-null   float64
#  35  10/2023       1688 non-null   float64
#  36  11/2023       2520 non-null   float64
#  37  12/2023       1836 non-null   float64
#  38  01/2024       2224 non-null   float64
#  39  02/2024       1860 non-null   float64
#  40  03/2024       751 non-null    float64
#  41  04/2024       2064 non-null   float64
#  42  05/2024       1185 non-null   float64
#  43  06/2024       2002 non-null   float64
#  44  07/2024       1705 non-null   float64
#  45  08/2024       2164 non-null   float64
#  46  09/2024       1784 non-null   float64
#  47  10/2024       2748 non-null   float64
#  48  11/2024       2407 non-null   float64
#  49  12/2024       2843 non-null   float64
# dtypes: float64(47), int64(2), object(1)
# memory usage: 2.6+ MB

# %%
# Open the dataset from webscraping, to get the latest meta description data

# %%
df2=pd.read_csv('StudyLink_DateConverted.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               303 non-null    object
#  1   h1_tags             231 non-null    object
#  2   word_count          303 non-null    int64
#  3   keywords            303 non-null    object
#  4   description         303 non-null    object
#  5   snapshot_url        303 non-null    object
#  6   Timestamp           303 non-null    object
#  7   description_length  303 non-null    int64
#  8   keyword_count       303 non-null    int64
#  9   month year          303 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 23.8+ KB

# %%
# Display column names to verify the correct name for 'Timestamp'
print(df2.columns)
# Out:
# Index(['title', 'h1_tags', 'word_count', 'keywords', 'description',
#        'snapshot_url', 'Timestamp', 'description_length', 'keyword_count',
#        'month year'],
#       dtype='object')

# %%
# Ensure the correct column name is used for datetime conversion
# Replace 'Timestamp' with the correct column name from the printed columns
correct_timestamp_column = 'Timestamp'  # Update this if necessary
df2[correct_timestamp_column] = pd.to_datetime(df2[correct_timestamp_column], errors='coerce')

# %%
# Find the row with the latest Timestamp
latest_row = df2.loc[df2['Timestamp'].idxmax()]

# %%
# Get the value in the 'keywords' column for the latest Timestamp
latest_description = latest_row['description']

# %%
print("Latest description:", latest_description)
# Out:
# Latest description: We help students make informed choices about their student finance, how to apply for it and manage it online.

# %%
# Add a new column 'description' to the first dataset

# %%
# Add a new column 'description'
df['description'] = latest_description

# %%
df.head()
# Out:
#                                     Keyword  EndRank  EndClicks  SearchVolume  \
# 0                                  academic       17         12        1200.0
# 1                      otago academic dates       35          0           0.0
# 2  university of auckland academic calendar       79          0           0.0
# 3     auckland university academic calendar       74          0           0.0
# 4                      academic history vuw       66          0           0.0
#
#    03/2021  04/2021  05/2021  06/2021  07/2021  08/2021  ...  04/2024  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN  ...      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN  ...      NaN
# 2      NaN      NaN      NaN     71.0      NaN      NaN  ...     91.0
# 3      NaN      NaN      NaN      NaN      NaN      NaN  ...     55.0
# 4      NaN      NaN      NaN      NaN      NaN      NaN  ...     66.0
#
#    05/2024  06/2024  07/2024  08/2024  09/2024  10/2024  11/2024  12/2024  \
# 0     18.0      NaN     16.0      NaN      NaN      NaN     17.0      NaN
# 1     39.0      NaN     35.0      NaN     36.0      NaN     35.0      NaN
# 2      NaN      NaN      NaN      NaN      NaN     80.0      NaN     79.0
# 3      NaN     84.0      NaN      NaN      NaN     74.0      NaN      NaN
# 4      NaN     70.0      NaN     77.0      NaN     66.0      NaN      NaN
#
#                                          description
# 0  We help students make informed choices about t...
# 1  We help students make informed choices about t...
# 2  We help students make informed choices about t...
# 3  We help students make informed choices about t...
# 4  We help students make informed choices about t...
#
# [5 rows x 51 columns]

# %%
# Perform TF-IDF analysis on 'Keyword' and 'description'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# %%
# Perform TF-IDF analysis on 'Keyword' and 'description'
df['Keyword'] = df['Keyword'].fillna('')
df['description'] = df['description'].fillna('')

tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Keyword'] + ' ' + df['description'])
df['TF-IDF_score'] = np.mean(tfidf_matrix.toarray(), axis=1)

# %%
df.head()
# Out:
#                                     Keyword  EndRank  EndClicks  SearchVolume  \
# 0                                  academic       17         12        1200.0
# 1                      otago academic dates       35          0           0.0
# 2  university of auckland academic calendar       79          0           0.0
# 3     auckland university academic calendar       74          0           0.0
# 4                      academic history vuw       66          0           0.0
#
#    03/2021  04/2021  05/2021  06/2021  07/2021  08/2021  ...  05/2024  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN  ...     18.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN  ...     39.0
# 2      NaN      NaN      NaN     71.0      NaN      NaN  ...      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN  ...      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN  ...      NaN
#
#    06/2024  07/2024  08/2024  09/2024  10/2024  11/2024  12/2024  \
# 0      NaN     16.0      NaN      NaN      NaN     17.0      NaN
# 1      NaN     35.0      NaN     36.0      NaN     35.0      NaN
# 2      NaN      NaN      NaN      NaN     80.0      NaN     79.0
# 3     84.0      NaN      NaN      NaN     74.0      NaN      NaN
# 4     70.0      NaN     77.0      NaN     66.0      NaN      NaN
#
#                                          description  TF-IDF_score
# 0  We help students make informed choices about t...      0.001933
# 1  We help students make informed choices about t...      0.002098
# 2  We help students make informed choices about t...      0.002211
# 3  We help students make informed choices about t...      0.002110
# 4  We help students make informed choices about t...      0.001977
#
# [5 rows x 52 columns]

# %%
df.to_csv('rank_keywords_studylink_cleaned_score.csv', index=False)

# %%
# Regression analysis on TF-IDF scores and the 'SearchVolume' (latest click number of the keyword)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('rank_keywords_studylink_cleaned_score.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6569 entries, 0 to 6568
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Keyword       6569 non-null   object
#  1   EndRank       6569 non-null   int64
#  2   EndClicks     6569 non-null   int64
#  3   SearchVolume  6569 non-null   float64
#  4   03/2021       0 non-null      float64
#  5   04/2021       522 non-null    float64
#  6   05/2021       316 non-null    float64
#  7   06/2021       142 non-null    float64
#  8   07/2021       1613 non-null   float64
#  9   08/2021       642 non-null    float64
#  10  09/2021       1094 non-null   float64
#  11  10/2021       1023 non-null   float64
#  12  11/2021       924 non-null    float64
#  13  12/2021       358 non-null    float64
#  14  01/2022       1415 non-null   float64
#  15  02/2022       325 non-null    float64
#  16  03/2022       533 non-null    float64
#  17  04/2022       1095 non-null   float64
#  18  05/2022       1017 non-null   float64
#  19  06/2022       1086 non-null   float64
#  20  07/2022       1462 non-null   float64
#  21  08/2022       1474 non-null   float64
#  22  09/2022       1296 non-null   float64
#  23  10/2022       1497 non-null   float64
#  24  11/2022       1474 non-null   float64
#  25  12/2022       1389 non-null   float64
#  26  01/2023       1541 non-null   float64
#  27  02/2023       1668 non-null   float64
#  28  03/2023       1603 non-null   float64
#  29  04/2023       1381 non-null   float64
#  30  05/2023       1427 non-null   float64
#  31  06/2023       1715 non-null   float64
#  32  07/2023       1569 non-null   float64
#  33  08/2023       1678 non-null   float64
#  34  09/2023       2314 non-null   float64
#  35  10/2023       1688 non-null   float64
#  36  11/2023       2520 non-null   float64
#  37  12/2023       1836 non-null   float64
#  38  01/2024       2224 non-null   float64
#  39  02/2024       1860 non-null   float64
#  40  03/2024       751 non-null    float64
#  41  04/2024       2064 non-null   float64
#  42  05/2024       1185 non-null   float64
#  43  06/2024       2002 non-null   float64
#  44  07/2024       1705 non-null   float64
#  45  08/2024       2164 non-null   float64
#  46  09/2024       1784 non-null   float64
#  47  10/2024       2748 non-null   float64
#  48  11/2024       2407 non-null   float64
#  49  12/2024       2843 non-null   float64
#  50  description   6569 non-null   object
#  51  TF-IDF_score  6569 non-null   float64
# dtypes: float64(48), int64(2), object(2)
# memory usage: 2.6+ MB

# %%
# Select relevant columns for regression
columns_of_interest = ['TF-IDF_score', 'SearchVolume']
if all(col in df.columns for col in columns_of_interest):
    df_subset = df[columns_of_interest].dropna()
else:
    raise ValueError("One or both columns 'TF-IDF_score' and 'SearchVolume' are missing in the dataset.")

# %%
# Method to identify outliers using boxplots and IQR (Interquartile Range)
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

# %%
# Detect outliers for both columns
outliers_tfidf, lower_tfidf, upper_tfidf = detect_outliers_iqr(df_subset, 'TF-IDF_score')
outliers_searchvolume, lower_searchvolume, upper_searchvolume = detect_outliers_iqr(df_subset, 'SearchVolume')

# %%
# Visualize outliers with boxplots
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y=df_subset['TF-IDF_score'])
plt.title('Outliers in TF-IDF_score')

plt.subplot(1, 2, 2)
sns.boxplot(y=df_subset['SearchVolume'])
plt.title('Outliers in SearchVolume')

plt.tight_layout()
plt.show()

# %%
# Display detected outliers
print("Outliers in 'TF-IDF_score':")
print(outliers_tfidf)

print("Outliers in 'searchvolume':")
print(outliers_searchvolume)
# Out:
# Outliers in 'TF-IDF_score':
#       TF-IDF_score  SearchVolume
# 218       0.002695         660.0
# 223       0.002651          20.0
# 776       0.002625           0.0
# 1608      0.002695        2500.0
# 2083      0.001722           0.0
# 2086      0.001760           0.0
# 2788      0.002725           0.0
# 2944      0.002695         720.0
# 3194      0.002695          40.0
# 3198      0.002668          80.0
# 3291      0.002695          20.0
# 3427      0.001336           0.0
# 3590      0.002695           0.0
# 3931      0.001540           0.0
# 4106      0.001641           0.0
# 4164      0.001658           0.0
# 4362      0.002668           0.0
# 4758      0.001568           0.0
# 4768      0.002695           0.0
# 5255      0.001600         100.0
# 5360      0.002618           0.0
# 5744      0.002695        2600.0
# 5745      0.002695         510.0
# 5895      0.002708           0.0
# Outliers in 'searchvolume':
#       TF-IDF_score  SearchVolume
# 0         0.001933        1200.0
# 5         0.002283        6400.0
# 6         0.002257         460.0
# 7         0.002177         240.0
# 8         0.002315          20.0
# ...            ...           ...
# 6390      0.002148          60.0
# 6391      0.002348         570.0
# 6392      0.002111         100.0
# 6393      0.002012         120.0
# 6417      0.002460       25100.0
#
# [1203 rows x 2 columns]

# %%
# Remove outliers from both columns
#df_subset = df_subset[(df_subset['TF-IDF_score'] >= lower_tfidf) & (df_subset['TF-IDF_score'] <= upper_tfidf)]
#df_subset = df_subset[(df_subset['SearchVolume'] >= lower_endclicks) & (df_subset['SearchVolume'] <= upper_endclicks)]

# %%
# Visualize cleaned data with boxplots
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y=df_subset['TF-IDF_score'])
plt.title('TF-IDF_score (Outliers Removed)')

plt.subplot(1, 2, 2)
sns.boxplot(y=df_subset['SearchVolume'])
plt.title('SearchVolume (Outliers Removed)')

plt.tight_layout()
plt.show()

# Display cleaned dataset information
print("Cleaned dataset after removing outliers:")
print(df_subset.info())
print(df_subset.head())
# Out:
# Cleaned dataset after removing outliers:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5352 entries, 1 to 6568
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TF-IDF_score  5352 non-null   float64
#  1   SearchVolume  5352 non-null   float64
# dtypes: float64(2)
# memory usage: 125.4 KB
# None
#     TF-IDF_score  SearchVolume
# 1       0.002098           0.0
# 2       0.002211           0.0
# 3       0.002110           0.0
# 4       0.001977           0.0
# 11      0.002337           0.0

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Define the independent (X) and dependent (y) variables
X = df['TF-IDF_score']
y = df['SearchVolume']

# Add a constant to the independent variable (required for statsmodels)
X = sm.add_constant(X)

# Perform the regression analysis
model = sm.OLS(y, X).fit()

# Print the regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           SearchVolume   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     5.295
# Date:                Wed, 01 Jan 2025   Prob (F-statistic):             0.0214
# Time:                        22:46:41   Log-Likelihood:                -65182.
# No. Observations:                6569   AIC:                         1.304e+05
# Df Residuals:                    6567   BIC:                         1.304e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const        -1734.4097    858.028     -2.021      0.043   -3416.424     -52.395
# TF-IDF_score  8.997e+05   3.91e+05      2.301      0.021    1.33e+05    1.67e+06
# ==============================================================================
# Omnibus:                    22184.283   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       4919900143.208
# Skew:                          60.549   Prob(JB):                         0.00
# Kurtosis:                    4240.961   Cond. No.                     6.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Residual Plot
import statsmodels.api as sm

X = sm.add_constant(df_subset['TF-IDF_score'])
y = df_subset['SearchVolume']

model = sm.OLS(y, X).fit()
residuals = model.resid

plt.figure(figsize=(8, 6))
sns.residplot(x=df_subset['TF-IDF_score'], y=residuals, lowess=True, line_kws={'color': 'red'})
plt.title('Residuals vs Fitted Values')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %%
# Log Transformation Example
df_subset['TF-IDF_score_log'] = np.log1p(df_subset['TF-IDF_score'])
df_subset['SearchVolume_log'] = np.log1p(df_subset['SearchVolume'])

# %%
# Re-run Regression with Transformed Variables
X_log = sm.add_constant(df_subset['TF-IDF_score_log'])
y_log = df_subset['SearchVolume_log']

model_log = sm.OLS(y_log, X_log).fit()
print(model_log.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       SearchVolume_log   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 01 Jan 2025   Prob (F-statistic):                nan
# Time:                        22:49:35   Log-Likelihood:                    inf
# No. Observations:                5352   AIC:                              -inf
# Df Residuals:                    5350   BIC:                              -inf
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                     0          0        nan        nan           0           0
# TF-IDF_score_log          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                     6.76e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.76e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\hxiuf\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\hxiuf\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# C:\Users\hxiuf\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:958: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\hxiuf\anaconda3\Lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)

# %%
# Regression model building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# %%
# Step 1: Scatter plot and correlation
plt.figure(figsize=(8, 6))
sns.scatterplot(x='TF-IDF_score', y='SearchVolume', data=df_subset)
plt.title('Scatter Plot of TF-IDF_score vs SearchVolume')
plt.xlabel('TF-IDF_score')
plt.ylabel('SearchVolume')
plt.show()

# %%
correlation = df['TF-IDF_score'].corr(df_subset['SearchVolume'])
print(f'Correlation Coefficient: {correlation:.2f}')
# Out:
# Correlation Coefficient: nan
# C:\Users\hxiuf\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\hxiuf\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5352 entries, 1 to 6568
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TF-IDF_score  5352 non-null   float64
#  1   SearchVolume  5352 non-null   float64
# dtypes: float64(2)
# memory usage: 125.4 KB

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Define the independent (X) and dependent (y) variables
X = df['TF-IDF_score']
y = df['EndClicks']

# Add a constant to the independent variable (required for statsmodels)
X = sm.add_constant(X)

# Perform the regression analysis
model = sm.OLS(y, X).fit()

# Print the regression summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              EndClicks   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.6464
# Date:                Wed, 01 Jan 2025   Prob (F-statistic):              0.421
# Time:                        21:44:32   Log-Likelihood:                -43018.
# No. Observations:                6569   AIC:                         8.604e+04
# Df Residuals:                    6567   BIC:                         8.605e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -19.3789     29.386     -0.659      0.510     -76.985      38.227
# TF-IDF_score  1.077e+04   1.34e+04      0.804      0.421   -1.55e+04     3.7e+04
# ==============================================================================
# Omnibus:                    23860.934   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       9521567787.574
# Skew:                          75.136   Prob(JB):                         0.00
# Kurtosis:                    5899.159   Cond. No.                     6.42e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.42e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Plot the regression line
plt.scatter(df['TF-IDF_score'], df['EndClicks'], color='blue', label='Data Points')
plt.plot(df['TF-IDF_score'], model.predict(X), color='red', label='Regression Line')
plt.xlabel('TF-IDF Score')
plt.ylabel('End Clicks')
plt.title('Regression Analysis: TF-IDF Score vs End Clicks')
plt.legend()
plt.show()
